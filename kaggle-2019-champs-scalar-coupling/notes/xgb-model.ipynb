# %%
# This is a copy of my private kaggle kernel: https://www.kaggle.com/joatom/xgb-model
# fork of https://www.kaggle.com/inversion/atomic-distance-benchmark/

#J-Coupling:https://www.youtube.com/watch?v=vnkk3eli1Hc

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.model_selection import KFold,GroupKFold
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from xgboost import plot_importance
from matplotlib import pyplot as plt

import gc
import psutil
import os
import time
from functools import reduce

print(os.listdir("../input"))
# Out:
# ['champs-scalar-coupling', 'main-features']

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error as mmse
from sklearn.metrics import mean_absolute_error as mmae

# %% [markdown]
# # General Functions

# %%
in_path='../input/champs-scalar-coupling/'
mf_path='../input/main-features/'

# %%
#train=pd.read_pickle(mf_path+'train_ext_1JHN.zip',compression='zip')
#train.head()

# %%
# https://www.kaggle.com/todnewman/keras-neural-net-for-champs/comments
def show_ram_usage():
    py = psutil.Process(os.getpid())
    print('RAM usage: {} GB'.format(py.memory_info()[0]/2. ** 30))

# %%
# https://www.kaggle.com/gemartin/load-data-reduce-memory-usage
# https://www.kaggle.com/c/champs-scalar-coupling/discussion/96655#latest-565815
# guiferviz comment

def reduce_memory_usage(df, deep=True, verbose=True, categories=True):
    # All types that we want to change for "lighter" ones.
    # int8 and float16 are not include because we cannot reduce
    # those data types.
    # float32 is not include because float16 has too low precision.
    numeric2reduce = ["int16", "int32", "int64", "float64"]
    start_mem = 0
    if verbose:
        start_mem = df.memory_usage().sum() / 1024**2

    for col, col_type in df.dtypes.iteritems():
        best_type = None
        if col_type == "object":
            df[col] = df[col].astype("category")
            best_type = "category"
        elif col_type in numeric2reduce:
            downcast = "integer" if "int" in str(col_type) else "float"
            df[col] = pd.to_numeric(df[col], downcast=downcast)
            best_type = df[col].dtype.name
        # Log the conversion performed.
        if verbose and best_type is not None and best_type != str(col_type):
            print(f"Column '{col}' converted from {col_type} to {best_type}")

    if verbose:
        end_mem = df.memory_usage().sum() / 1024**2
        diff_mem = start_mem - end_mem
        percent_mem = 100 * diff_mem / start_mem
        print(f"Memory usage decreased from"
              f" {start_mem:.2f}MB to {end_mem:.2f}MB"
              f" ({diff_mem:.2f}MB, {percent_mem:.2f}% reduction)")
    return df

# %% [markdown]
# # xgb

# %%
wctn_num=8
#path = Path('../input')

np.random.seed(2019)

fin_preds =[]
fin_preds_idx =[]
fin_train_idx=[]
ras_all=[]
raa_all=[]
nn_preds_valid_a =[]
y_valid_nn_a =[]

#procs = [FillMissing, Categorify, Normalize]
bs= 256

dep_var = 'scalar_coupling_constant'

# %%
show_ram_usage()
# Out:
# RAM usage: 0.1481475830078125 GB

# %%
#train.groupby('type')['x_0'].count()

# %%
#train[dep_var].hist(by=train['type'],figsize=(10,10))

# %%
#X[(X['scalar_coupling_constant']>190) & (X['type']=='1JHC')] #.groupby('type').count()
#train['type'].unique()

# %%
# %%time

features=['mulliken_charge_0','mulliken_charge_1',
          'atom_0','num_atoms_in_mol_x','nn1_0','nn1_dist_0','nn2_0','nn2_dist_0','nn3_0','nn3_dist_0','nn4_0','nn4_dist_0','nn5_0','nn5_dist_0','nn6_0',
          'nn6_dist_0','nn7_0','nn7_dist_0','nn8_0','nn8_dist_0','nn9_0','nn9_dist_0','atom_1','nn1_1','nn1_dist_1','nn2_1','nn2_dist_1','nn3_1','nn3_dist_1',
          'nn4_1','nn4_dist_1','nn5_1','nn5_dist_1','nn6_1','nn6_dist_1','nn7_1','nn7_dist_1','nn8_1','nn8_dist_1','nn9_1','nn9_dist_1','C','F','H','N','O',
          #'common_nn_0',
          #'common_nn_1',
          'common_nn_dist_1',
          #'common_nn_2',
          'common_nn_dist_2',
          #'common_nn_3',
          'common_nn_dist_3',
          #'common_nn_4',
          'common_nn_dist_4',
          #'common_nn_5',
          'common_nn_dist_5',
          #'common_nn_6',
          'common_nn_dist_6',
          #'common_nn_7',
          'common_nn_dist_7',
          #'common_nn_8',
          'common_nn_dist_8',
          #'common_nn_9',
          'common_nn_dist_9',
          #'nn_1_0_exists','nn_1_1_exists','nn_2_0_exists','nn_2_1_exists','nn_3_0_exists','nn_3_1_exists','nn_4_0_exists','nn_4_1_exists',
          #'nn_5_0_exists','nn_5_1_exists','nn_6_0_exists','nn_6_1_exists','nn_7_0_exists','nn_7_1_exists','nn_8_0_exists','nn_8_1_exists','nn_9_0_exists',
          #'nn_9_1_exists',
          #'2J_nn','3J_nn',
          'dist','dist_cos','dist_mol_c_0','dist_mol_c_1','2J_angle','3J_angle','dist_nn_0_1','dist_nn_1_1','dist_nn_0_2',
          'dist_nn_1_2','dist_nn_0_3','dist_nn_1_3','dist_nn_0_4','dist_nn_1_4','dist_nn_0_5','dist_nn_1_5','dist_nn_0_6','dist_nn_1_6','dist_nn_0_7',
          'dist_nn_1_7','dist_nn_0_8','dist_nn_1_8','dist_nn_0_9','dist_nn_1_9','dihedral','bonds',
          #'yukawa_0','yukawa_1',
          #'coulomb_0','coulomb_1',
          'vander_0','vander_1']

types_to_run = ['3JHC', '2JHC', '1JHC', '2JHH', '1JHN', '2JHN', '3JHH', '3JHN'] #train['type'].unique() ## #['3JHC']:#['3JHC']:#['1JHN']#

np.random.seed(2019)
for wctn in types_to_run:
    print('')
    print('###############',wctn,'###################')
    print('')
    train=pd.read_pickle(mf_path+'train_ext_'+wctn+'.zip',compression='zip')
    test=pd.read_pickle(mf_path+'test_ext_'+wctn+'.zip',compression='zip')
    
    #https://www.kaggle.com/titericz/giba-r-data-table-simple-features-1-17-lb
    #train['yukawa_0']= np.exp(-train['nn1_dist_0'])+np.exp(-train['nn2_dist_0'])+np.exp(-train['nn3_dist_0'])+np.exp(-train['nn4_dist_0'])#+np.exp(-train['nn5_dist_0'])
    #train['yukawa_1']= np.exp(-train['nn1_dist_1'])+np.exp(-train['nn2_dist_1'])+np.exp(-train['nn3_dist_1'])+np.exp(-train['nn4_dist_1'])#+np.exp(-train['nn5_dist_1'])
    #test['yukawa_0']= np.exp(-test['nn1_dist_0'])+np.exp(-test['nn2_dist_0'])+np.exp(-test['nn3_dist_0'])+np.exp(-test['nn4_dist_0'])#+np.exp(-test['nn5_dist_0'])
    #test['yukawa_1']= np.exp(-test['nn1_dist_1'])+np.exp(-test['nn2_dist_1'])+np.exp(-test['nn3_dist_1'])+np.exp(-test['nn4_dist_1'])#+np.exp(-test['nn5_dist_1'])
    
    #train['coulomb_0']= 1/(train['nn1_dist_0']+1e-8)+1/(train['nn2_dist_0']+1e-8)+1/(train['nn3_dist_0']+1e-8)+1/(train['nn4_dist_0']+1e-8)#+np.exp(-train['nn5_dist_0'])
    #train['coulomb_1']= 1/(train['nn1_dist_1']+1e-8)+1/(train['nn2_dist_1']+1e-8)+1/(train['nn3_dist_1']+1e-8)+1/(train['nn4_dist_1']+1e-8)#+np.exp(-train['nn5_dist_1'])
    #test['coulomb_0']= 1/(test['nn1_dist_0']+1e-8)+1/(test['nn2_dist_0']+1e-8)+1/(test['nn3_dist_0']+1e-8)+1/(test['nn4_dist_0']+1e-8)#+np.exp(-test['nn5_dist_0'])
    #test['coulomb_1']= 1/(test['nn1_dist_1']+1e-8)+1/(test['nn2_dist_1']+1e-8)+1/(test['nn3_dist_1']+1e-8)+1/(test['nn4_dist_1']+1e-8)#+np.exp(-test['nn5_dist_1'])
    
    train['vander_0']= 1/((train['nn1_dist_0']+1e-8)**3)+1/((train['nn2_dist_0']+1e-8)**3)+1/((train['nn3_dist_0']+1e-8)**3)+1/((train['nn4_dist_0']+1e-8)**3)#+np.exp(-train['nn5_dist_0'])
    train['vander_1']= 1/((train['nn1_dist_1']+1e-8)**3)+1/((train['nn2_dist_1']+1e-8)**3)+1/((train['nn3_dist_1']+1e-8)**3)+1/((train['nn4_dist_1']+1e-8)**3)#+np.exp(-train['nn5_dist_1'])
    test['vander_0']= 1/((test['nn1_dist_0']+1e-8)**3)+1/((test['nn2_dist_0']+1e-8)**3)+1/((test['nn3_dist_0']+1e-8)**3)+1/((test['nn4_dist_0']+1e-8)**3)#+np.exp(-test['nn5_dist_0'])
    test['vander_1']= 1/((test['nn1_dist_1']+1e-8)**3)+1/((test['nn2_dist_1']+1e-8)**3)+1/((test['nn3_dist_1']+1e-8)**3)+1/((test['nn4_dist_1']+1e-8)**3)#+np.exp(-test['nn5_dist_1'])
        
    
    train=reduce_memory_usage(train)
    test=reduce_memory_usage(test)
    
    gc.collect()
    show_ram_usage()
    
    cat_names = ['atom_1', 'atom_0','nn1_0','nn2_0','nn3_0','nn4_0','nn5_0','nn6_0','nn1_1','nn2_1','nn3_1','nn4_1','nn5_1','nn6_1']
    cont_names = list(set(train.columns)-set(cat_names+[dep_var,'type','id'])) 
    #print(cat_names, cont_names)
    
    print(wctn,'started...')
    id_train_wctn=train[train['type']==wctn]['id']
    y_train_wctn=train[train['type']==wctn][dep_var]
    X_train_wctn=train[train['type']==wctn].drop(['id','type',dep_var],axis=1)#.reset_index()
    X_train_wctn=X_train_wctn[features]
    #print(X_train_wctn.info(200))
    id_test_wctn=test[test['type']==wctn]['id']
    X_test_wctn=test[test['type']==wctn].drop(['id','type'],axis=1)
    X_test_wctn=X_test_wctn[features]


    #print(X_test_wctn.info(200))
    train = None
    test = None
    gc.collect()
    
    predsNN=[None]
    
    yoof = np.zeros(len(X_train_wctn))
    yhat = np.zeros(len(X_test_wctn))

    lr=0.4
    n_est=20000
    n_splits = 5
    
    if wctn in ['1JHN','2JHN','3JHN']:
        lr=0.1
        n_est=20000
        n_splits = 5
    elif wctn in ['2JHH','3JHH']:
        n_est=20000
        lr=0.4
        n_splits = 5
    elif wctn in ['1JHC','2JHC',]:
        lr=0.4
        n_est=20000
        n_splits=5
    elif wctn in ['3JHC']:
        lr=0.4
        n_est=22000
        n_splits=5
    
    gkf = KFold(n_splits=n_splits, shuffle=True, random_state=2019)

    fold = 0
    for in_index, oof_index in gkf.split(X_train_wctn, y_train_wctn):
        fold += 1
        print(f'fold {fold} of {n_splits}')
        X_in, X_oof = X_train_wctn.values[in_index], X_train_wctn.values[oof_index]
        y_in, y_oof = y_train_wctn.values[in_index], y_train_wctn.values[oof_index]
        
        model = XGBRegressor(n_estimators=n_est, learning_rate=lr, random_state=2019, tree_method = 'gpu_exact')#0.1

        model.fit(X_in, y_in, early_stopping_rounds=20, eval_set=[(X_oof, y_oof)], verbose=400, eval_metric = 'mae')

        print('## lr:',lr,'n_est:',n_est)
        print('Best iteration: '+ str(model.best_iteration), 'Best ntree_limit: '+ str(model.best_ntree_limit), 'Best score:', str(model.best_score)) #model.best_score,
        
        yoof[oof_index] = model.predict(X_oof)
        yhat += model.predict(X_test_wctn.values)
        gc.collect()

    yhat /= n_splits
    
    raa=mmae(yoof, y_train_wctn)
    print(wctn,'mae',raa)
    raa_all.append(raa)
    
    # for analysis
    nn_preds_valid_a.append(yoof)
    y_valid_nn_a.append(y_train_wctn)
    fin_train_idx.append(np.array(id_train_wctn))

    gc.collect()
    
    print(wctn,raa,len(X_test_wctn))
    fin_preds.append(np.array(yhat))
    fin_preds_idx.append(np.array(id_test_wctn))
    
    y_train_wctn=None
    X_train_wctn=None
    id_test_wctn=None
    X_test_wctn=None
    learn = None
    gc.collect()
    show_ram_usage()
# Out:
# ############### 3JHC ###################
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Column 'nn3_0' converted from int16 to int8
# Column 'nn4_0' converted from int16 to int8
# Column 'nn5_0' converted from int16 to int8
# Column 'nn3_1' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'nn5_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 920.42MB to 900.26MB (20.17MB, 2.19% reduction)
# Column 'nn4_0' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 490.18MB to 482.44MB (7.74MB, 1.58% reduction)
# RAM usage: 1.7700042724609375 GB
# 3JHC started...
# fold 1 of 5
# [17:02:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.31454
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.705733
# [800]	validation_0-mae:0.628845
# [1200]	validation_0-mae:0.586603
# [1600]	validation_0-mae:0.558231
# [2000]	validation_0-mae:0.53766
# [2400]	validation_0-mae:0.521444
# [2800]	validation_0-mae:0.508449
# [3200]	validation_0-mae:0.497173
# [3600]	validation_0-mae:0.487473
# [4000]	validation_0-mae:0.480085
# [4400]	validation_0-mae:0.473216
# [4800]	validation_0-mae:0.466437
# [5200]	validation_0-mae:0.461042
# [5600]	validation_0-mae:0.45591
# [6000]	validation_0-mae:0.450821
# [6400]	validation_0-mae:0.446198
# [6800]	validation_0-mae:0.44239
# [7200]	validation_0-mae:0.43875
# [7600]	validation_0-mae:0.43562
# [8000]	validation_0-mae:0.432659
# [8400]	validation_0-mae:0.429728
# [8800]	validation_0-mae:0.426928
# [9200]	validation_0-mae:0.424524
# [9600]	validation_0-mae:0.421933
# [10000]	validation_0-mae:0.419525
# [10400]	validation_0-mae:0.41763
# [10800]	validation_0-mae:0.415728
# [11200]	validation_0-mae:0.413792
# [11600]	validation_0-mae:0.411703
# [12000]	validation_0-mae:0.409811
# [12400]	validation_0-mae:0.40804
# [12800]	validation_0-mae:0.406632
# [13200]	validation_0-mae:0.405193
# [13600]	validation_0-mae:0.403772
# [14000]	validation_0-mae:0.402569
# [14400]	validation_0-mae:0.40132
# [14800]	validation_0-mae:0.400183
# [15200]	validation_0-mae:0.398991
# [15600]	validation_0-mae:0.397979
# [16000]	validation_0-mae:0.397041
# [16400]	validation_0-mae:0.396124
# [16800]	validation_0-mae:0.395151
# [17200]	validation_0-mae:0.394282
# [17600]	validation_0-mae:0.393523
# [18000]	validation_0-mae:0.392762
# Stopping. Best iteration:
# [18198]	validation_0-mae:0.392438
#
# ## lr: 0.4 n_est: 22000
# Best iteration: 18198 Best ntree_limit: 18199 Best score: 0.392438
# fold 2 of 5
# [17:43:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.31281
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.705917
# [800]	validation_0-mae:0.626464
# [1200]	validation_0-mae:0.584298
# [1600]	validation_0-mae:0.555939
# [2000]	validation_0-mae:0.536521
# [2400]	validation_0-mae:0.520003
# [2800]	validation_0-mae:0.507029
# [3200]	validation_0-mae:0.496974
# [3600]	validation_0-mae:0.487396
# [4000]	validation_0-mae:0.479103
# [4400]	validation_0-mae:0.4716
# [4800]	validation_0-mae:0.465228
# [5200]	validation_0-mae:0.459547
# [5600]	validation_0-mae:0.454553
# [6000]	validation_0-mae:0.449888
# [6400]	validation_0-mae:0.445829
# [6800]	validation_0-mae:0.442152
# [7200]	validation_0-mae:0.43849
# [7600]	validation_0-mae:0.435089
# [8000]	validation_0-mae:0.431891
# [8400]	validation_0-mae:0.429263
# [8800]	validation_0-mae:0.426616
# [9200]	validation_0-mae:0.424034
# [9600]	validation_0-mae:0.42189
# [10000]	validation_0-mae:0.419432
# [10400]	validation_0-mae:0.417277
# [10800]	validation_0-mae:0.415413
# [11200]	validation_0-mae:0.413385
# [11600]	validation_0-mae:0.411681
# [12000]	validation_0-mae:0.410047
# [12400]	validation_0-mae:0.408605
# [12800]	validation_0-mae:0.407091
# [13200]	validation_0-mae:0.405709
# [13600]	validation_0-mae:0.404447
# [14000]	validation_0-mae:0.403091
# [14400]	validation_0-mae:0.40178
# [14800]	validation_0-mae:0.400605
# [15200]	validation_0-mae:0.399443
# [15600]	validation_0-mae:0.398384
# [16000]	validation_0-mae:0.397381
# [16400]	validation_0-mae:0.396407
# [16800]	validation_0-mae:0.395413
# [17200]	validation_0-mae:0.394587
# [17600]	validation_0-mae:0.393528
# [18000]	validation_0-mae:0.39267
# [18400]	validation_0-mae:0.391997
# [18800]	validation_0-mae:0.391303
# [19200]	validation_0-mae:0.390658
# [19600]	validation_0-mae:0.389973
# Stopping. Best iteration:
# [19979]	validation_0-mae:0.38925
#
# ## lr: 0.4 n_est: 22000
# Best iteration: 19979 Best ntree_limit: 19980 Best score: 0.38925
# fold 3 of 5
# [18:27:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.31274
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.708918
# [800]	validation_0-mae:0.6289
# [1200]	validation_0-mae:0.586839
# [1600]	validation_0-mae:0.559694
# [2000]	validation_0-mae:0.538639
# [2400]	validation_0-mae:0.522429
# [2800]	validation_0-mae:0.51018
# [3200]	validation_0-mae:0.499334
# [3600]	validation_0-mae:0.489976
# [4000]	validation_0-mae:0.481585
# [4400]	validation_0-mae:0.474464
# [4800]	validation_0-mae:0.467878
# [5200]	validation_0-mae:0.461885
# [5600]	validation_0-mae:0.456926
# [6000]	validation_0-mae:0.452242
# [6400]	validation_0-mae:0.448125
# [6800]	validation_0-mae:0.444066
# [7200]	validation_0-mae:0.44051
# [7600]	validation_0-mae:0.437232
# [8000]	validation_0-mae:0.434358
# [8400]	validation_0-mae:0.431237
# [8800]	validation_0-mae:0.428719
# [9200]	validation_0-mae:0.426319
# [9600]	validation_0-mae:0.423943
# [10000]	validation_0-mae:0.42175
# [10400]	validation_0-mae:0.419638
# [10800]	validation_0-mae:0.417655
# [11200]	validation_0-mae:0.416008
# [11600]	validation_0-mae:0.414264
# [12000]	validation_0-mae:0.412553
# [12400]	validation_0-mae:0.410976
# [12800]	validation_0-mae:0.409431
# [13200]	validation_0-mae:0.408
# [13600]	validation_0-mae:0.406705
# [14000]	validation_0-mae:0.405434
# [14400]	validation_0-mae:0.404251
# [14800]	validation_0-mae:0.403133
# [15200]	validation_0-mae:0.401973
# [15600]	validation_0-mae:0.400941
# [16000]	validation_0-mae:0.3999
# [16400]	validation_0-mae:0.398839
# [16800]	validation_0-mae:0.397837
# [17200]	validation_0-mae:0.396936
# [17600]	validation_0-mae:0.396088
# [18000]	validation_0-mae:0.395345
# [18400]	validation_0-mae:0.394521
# [18800]	validation_0-mae:0.393734
# [19200]	validation_0-mae:0.392994
# Stopping. Best iteration:
# [19398]	validation_0-mae:0.392698
#
# ## lr: 0.4 n_est: 22000
# Best iteration: 19398 Best ntree_limit: 19399 Best score: 0.392698
# fold 4 of 5
# [19:10:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.31174
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.713344
# [800]	validation_0-mae:0.63296
# [1200]	validation_0-mae:0.590149
# [1600]	validation_0-mae:0.561069
# [2000]	validation_0-mae:0.539989
# [2400]	validation_0-mae:0.523835
# [2800]	validation_0-mae:0.510531
# [3200]	validation_0-mae:0.499425
# [3600]	validation_0-mae:0.489272
# [4000]	validation_0-mae:0.481342
# [4400]	validation_0-mae:0.473768
# [4800]	validation_0-mae:0.467395
# [5200]	validation_0-mae:0.461463
# [5600]	validation_0-mae:0.456436
# [6000]	validation_0-mae:0.451749
# [6400]	validation_0-mae:0.447504
# [6800]	validation_0-mae:0.443762
# [7200]	validation_0-mae:0.440091
# [7600]	validation_0-mae:0.436436
# [8000]	validation_0-mae:0.432825
# [8400]	validation_0-mae:0.429843
# [8800]	validation_0-mae:0.4271
# [9200]	validation_0-mae:0.424515
# [9600]	validation_0-mae:0.422017
# [10000]	validation_0-mae:0.420043
# [10400]	validation_0-mae:0.418189
# [10800]	validation_0-mae:0.416198
# [11200]	validation_0-mae:0.414389
# [11600]	validation_0-mae:0.412583
# [12000]	validation_0-mae:0.410819
# [12400]	validation_0-mae:0.409284
# [12800]	validation_0-mae:0.407742
# [13200]	validation_0-mae:0.406277
# [13600]	validation_0-mae:0.405053
# [14000]	validation_0-mae:0.4037
# [14400]	validation_0-mae:0.402406
# [14800]	validation_0-mae:0.401352
# [15200]	validation_0-mae:0.4003
# [15600]	validation_0-mae:0.399236
# [16000]	validation_0-mae:0.398168
# [16400]	validation_0-mae:0.397075
# [16800]	validation_0-mae:0.396068
# [17200]	validation_0-mae:0.39524
# [17600]	validation_0-mae:0.394279
# [18000]	validation_0-mae:0.393478
# Stopping. Best iteration:
# [18042]	validation_0-mae:0.393409
#
# ## lr: 0.4 n_est: 22000
# Best iteration: 18042 Best ntree_limit: 18043 Best score: 0.393409
# fold 5 of 5
# [19:50:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.31847
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.709721
# [800]	validation_0-mae:0.628217
# [1200]	validation_0-mae:0.586954
# [1600]	validation_0-mae:0.55868
# [2000]	validation_0-mae:0.539386
# [2400]	validation_0-mae:0.523239
# [2800]	validation_0-mae:0.511524
# [3200]	validation_0-mae:0.500642
# [3600]	validation_0-mae:0.491363
# [4000]	validation_0-mae:0.483548
# [4400]	validation_0-mae:0.476105
# [4800]	validation_0-mae:0.469422
# [5200]	validation_0-mae:0.463579
# [5600]	validation_0-mae:0.458225
# [6000]	validation_0-mae:0.453453
# [6400]	validation_0-mae:0.449127
# [6800]	validation_0-mae:0.445082
# [7200]	validation_0-mae:0.441183
# [7600]	validation_0-mae:0.437717
# [8000]	validation_0-mae:0.434361
# [8400]	validation_0-mae:0.431555
# [8800]	validation_0-mae:0.42911
# [9200]	validation_0-mae:0.426574
# [9600]	validation_0-mae:0.424214
# [10000]	validation_0-mae:0.422093
# [10400]	validation_0-mae:0.419871
# [10800]	validation_0-mae:0.417907
# [11200]	validation_0-mae:0.416036
# [11600]	validation_0-mae:0.414151
# [12000]	validation_0-mae:0.412281
# [12400]	validation_0-mae:0.410689
# [12800]	validation_0-mae:0.40922
# [13200]	validation_0-mae:0.407826
# [13600]	validation_0-mae:0.406507
# [14000]	validation_0-mae:0.405336
# [14400]	validation_0-mae:0.40416
# [14800]	validation_0-mae:0.402955
# [15200]	validation_0-mae:0.401756
# [15600]	validation_0-mae:0.400535
# [16000]	validation_0-mae:0.399544
# [16400]	validation_0-mae:0.398663
# [16800]	validation_0-mae:0.397697
# [17200]	validation_0-mae:0.396868
# [17600]	validation_0-mae:0.395993
# [18000]	validation_0-mae:0.395088
# [18400]	validation_0-mae:0.394348
# [18800]	validation_0-mae:0.39364
# [19200]	validation_0-mae:0.39287
# [19600]	validation_0-mae:0.392123
# [20000]	validation_0-mae:0.391417
# [20400]	validation_0-mae:0.39081
# [20800]	validation_0-mae:0.390247
# [21200]	validation_0-mae:0.389705
# [21600]	validation_0-mae:0.389025
# Stopping. Best iteration:
# [21718]	validation_0-mae:0.388868
#
# ## lr: 0.4 n_est: 22000
# Best iteration: 21718 Best ntree_limit: 21719 Best score: 0.388868
# 3JHC mae 0.3913328154398943
# 3JHC 0.3913328154398943 811999
# RAM usage: 3.7092361450195312 GB
#
# ############### 2JHC ###################
#
# Column 'nn3_0' converted from int16 to int8
# Column 'nn4_0' converted from int16 to int8
# Column 'nn3_1' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 695.12MB to 682.07MB (13.05MB, 1.88% reduction)
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 370.14MB to 365.46MB (4.68MB, 1.26% reduction)
# RAM usage: 4.688037872314453 GB
# 2JHC started...
# fold 1 of 5
# [20:39:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.40425
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.647289
# [800]	validation_0-mae:0.571495
# [1200]	validation_0-mae:0.533896
# [1600]	validation_0-mae:0.509276
# [2000]	validation_0-mae:0.49137
# [2400]	validation_0-mae:0.476812
# [2800]	validation_0-mae:0.464883
# [3200]	validation_0-mae:0.455405
# [3600]	validation_0-mae:0.447312
# [4000]	validation_0-mae:0.440225
# [4400]	validation_0-mae:0.433903
# [4800]	validation_0-mae:0.428812
# [5200]	validation_0-mae:0.423285
# [5600]	validation_0-mae:0.419186
# [6000]	validation_0-mae:0.414896
# [6400]	validation_0-mae:0.411285
# [6800]	validation_0-mae:0.407969
# [7200]	validation_0-mae:0.404967
# [7600]	validation_0-mae:0.402345
# [8000]	validation_0-mae:0.399884
# [8400]	validation_0-mae:0.397502
# [8800]	validation_0-mae:0.395194
# [9200]	validation_0-mae:0.392976
# [9600]	validation_0-mae:0.391067
# [10000]	validation_0-mae:0.389377
# [10400]	validation_0-mae:0.387784
# [10800]	validation_0-mae:0.386207
# [11200]	validation_0-mae:0.384681
# [11600]	validation_0-mae:0.383319
# [12000]	validation_0-mae:0.382235
# [12400]	validation_0-mae:0.381136
# [12800]	validation_0-mae:0.379868
# [13200]	validation_0-mae:0.378764
# [13600]	validation_0-mae:0.377759
# Stopping. Best iteration:
# [13795]	validation_0-mae:0.377296
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 13795 Best ntree_limit: 13796 Best score: 0.377296
# fold 2 of 5
# [21:02:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.39581
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.649926
# [800]	validation_0-mae:0.575733
# [1200]	validation_0-mae:0.537286
# [1600]	validation_0-mae:0.512409
# [2000]	validation_0-mae:0.494195
# [2400]	validation_0-mae:0.478926
# [2800]	validation_0-mae:0.46689
# [3200]	validation_0-mae:0.457339
# [3600]	validation_0-mae:0.449328
# [4000]	validation_0-mae:0.441824
# [4400]	validation_0-mae:0.435802
# [4800]	validation_0-mae:0.429796
# [5200]	validation_0-mae:0.424782
# [5600]	validation_0-mae:0.420616
# [6000]	validation_0-mae:0.416761
# [6400]	validation_0-mae:0.413508
# [6800]	validation_0-mae:0.410623
# [7200]	validation_0-mae:0.407349
# [7600]	validation_0-mae:0.40479
# [8000]	validation_0-mae:0.402179
# [8400]	validation_0-mae:0.399955
# [8800]	validation_0-mae:0.397797
# [9200]	validation_0-mae:0.395527
# [9600]	validation_0-mae:0.39352
# [10000]	validation_0-mae:0.39148
# [10400]	validation_0-mae:0.390239
# [10800]	validation_0-mae:0.388699
# [11200]	validation_0-mae:0.387083
# [11600]	validation_0-mae:0.385733
# Stopping. Best iteration:
# [11756]	validation_0-mae:0.38529
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 11756 Best ntree_limit: 11757 Best score: 0.38529
# fold 3 of 5
# [21:21:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.3963
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.652792
# [800]	validation_0-mae:0.57746
# [1200]	validation_0-mae:0.539701
# [1600]	validation_0-mae:0.514981
# [2000]	validation_0-mae:0.496785
# [2400]	validation_0-mae:0.482088
# [2800]	validation_0-mae:0.469671
# [3200]	validation_0-mae:0.459716
# [3600]	validation_0-mae:0.451279
# [4000]	validation_0-mae:0.444204
# [4400]	validation_0-mae:0.437983
# [4800]	validation_0-mae:0.431772
# [5200]	validation_0-mae:0.427115
# [5600]	validation_0-mae:0.422937
# [6000]	validation_0-mae:0.419029
# [6400]	validation_0-mae:0.415417
# [6800]	validation_0-mae:0.412149
# [7200]	validation_0-mae:0.409018
# [7600]	validation_0-mae:0.406155
# [8000]	validation_0-mae:0.403591
# [8400]	validation_0-mae:0.401294
# [8800]	validation_0-mae:0.399009
# [9200]	validation_0-mae:0.396985
# [9600]	validation_0-mae:0.394886
# [10000]	validation_0-mae:0.393371
# [10400]	validation_0-mae:0.391592
# [10800]	validation_0-mae:0.390092
# [11200]	validation_0-mae:0.388688
# [11600]	validation_0-mae:0.387502
# [12000]	validation_0-mae:0.386294
# [12400]	validation_0-mae:0.384971
# [12800]	validation_0-mae:0.383869
# [13200]	validation_0-mae:0.382679
# [13600]	validation_0-mae:0.381492
# [14000]	validation_0-mae:0.380579
# [14400]	validation_0-mae:0.379657
# [14800]	validation_0-mae:0.378826
# Stopping. Best iteration:
# [14875]	validation_0-mae:0.378678
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 14875 Best ntree_limit: 14876 Best score: 0.378678
# fold 4 of 5
# [21:45:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.38786
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.644399
# [800]	validation_0-mae:0.570879
# [1200]	validation_0-mae:0.533606
# [1600]	validation_0-mae:0.509982
# [2000]	validation_0-mae:0.491402
# [2400]	validation_0-mae:0.477053
# [2800]	validation_0-mae:0.465577
# [3200]	validation_0-mae:0.455413
# [3600]	validation_0-mae:0.447419
# [4000]	validation_0-mae:0.44018
# [4400]	validation_0-mae:0.433784
# [4800]	validation_0-mae:0.428554
# [5200]	validation_0-mae:0.42355
# [5600]	validation_0-mae:0.419328
# [6000]	validation_0-mae:0.415494
# [6400]	validation_0-mae:0.411922
# [6800]	validation_0-mae:0.408636
# [7200]	validation_0-mae:0.40572
# [7600]	validation_0-mae:0.402927
# [8000]	validation_0-mae:0.40049
# [8400]	validation_0-mae:0.397941
# [8800]	validation_0-mae:0.395783
# [9200]	validation_0-mae:0.394043
# [9600]	validation_0-mae:0.391842
# [10000]	validation_0-mae:0.390151
# Stopping. Best iteration:
# [10004]	validation_0-mae:0.390146
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 10004 Best ntree_limit: 10005 Best score: 0.390146
# fold 5 of 5
# [22:02:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.38709
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.650603
# [800]	validation_0-mae:0.574238
# [1200]	validation_0-mae:0.537054
# [1600]	validation_0-mae:0.510346
# [2000]	validation_0-mae:0.491091
# [2400]	validation_0-mae:0.476496
# [2800]	validation_0-mae:0.464342
# [3200]	validation_0-mae:0.455096
# [3600]	validation_0-mae:0.446597
# [4000]	validation_0-mae:0.43933
# [4400]	validation_0-mae:0.432778
# [4800]	validation_0-mae:0.427316
# [5200]	validation_0-mae:0.422464
# [5600]	validation_0-mae:0.418323
# [6000]	validation_0-mae:0.414196
# [6400]	validation_0-mae:0.410739
# [6800]	validation_0-mae:0.407603
# [7200]	validation_0-mae:0.404644
# [7600]	validation_0-mae:0.401858
# [8000]	validation_0-mae:0.399393
# [8400]	validation_0-mae:0.397241
# [8800]	validation_0-mae:0.395318
# [9200]	validation_0-mae:0.393175
# [9600]	validation_0-mae:0.391421
# [10000]	validation_0-mae:0.38978
# [10400]	validation_0-mae:0.388007
# [10800]	validation_0-mae:0.386403
# [11200]	validation_0-mae:0.384773
# [11600]	validation_0-mae:0.383607
# [12000]	validation_0-mae:0.382479
# [12400]	validation_0-mae:0.381273
# [12800]	validation_0-mae:0.380017
# [13200]	validation_0-mae:0.378849
# [13600]	validation_0-mae:0.377805
# [14000]	validation_0-mae:0.376815
# [14400]	validation_0-mae:0.375968
# [14800]	validation_0-mae:0.375109
# [15200]	validation_0-mae:0.374283
# [15600]	validation_0-mae:0.373419
# [16000]	validation_0-mae:0.372727
# Stopping. Best iteration:
# [16152]	validation_0-mae:0.372444
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 16152 Best ntree_limit: 16153 Best score: 0.372444
# 2JHC mae 0.3807708923181608
# 2JHC 0.3807708923181608 613138
# RAM usage: 3.832752227783203 GB
#
# ############### 1JHC ###################
#
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 432.32MB to 426.90MB (5.41MB, 1.25% reduction)
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 229.76MB to 226.86MB (2.90MB, 1.26% reduction)
# RAM usage: 4.383586883544922 GB
# 1JHC started...
# fold 1 of 5
# [22:28:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:56.6944
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:1.40134
# [800]	validation_0-mae:1.23761
# [1200]	validation_0-mae:1.15602
# [1600]	validation_0-mae:1.10005
# [2000]	validation_0-mae:1.05898
# [2400]	validation_0-mae:1.02833
# [2800]	validation_0-mae:1.00322
# [3200]	validation_0-mae:0.983322
# [3600]	validation_0-mae:0.966991
# [4000]	validation_0-mae:0.952
# [4400]	validation_0-mae:0.93883
# [4800]	validation_0-mae:0.927112
# [5200]	validation_0-mae:0.918307
# [5600]	validation_0-mae:0.910005
# [6000]	validation_0-mae:0.902257
# [6400]	validation_0-mae:0.895543
# [6800]	validation_0-mae:0.889901
# [7200]	validation_0-mae:0.884257
# [7600]	validation_0-mae:0.879512
# [8000]	validation_0-mae:0.874519
# [8400]	validation_0-mae:0.870243
# [8800]	validation_0-mae:0.866567
# [9200]	validation_0-mae:0.863084
# Stopping. Best iteration:
# [9432]	validation_0-mae:0.861198
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 9432 Best ntree_limit: 9433 Best score: 0.861198
# fold 2 of 5
# [22:38:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:56.6956
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:1.39291
# [800]	validation_0-mae:1.22521
# [1200]	validation_0-mae:1.14215
# [1600]	validation_0-mae:1.0858
# [2000]	validation_0-mae:1.04493
# [2400]	validation_0-mae:1.01332
# [2800]	validation_0-mae:0.988924
# [3200]	validation_0-mae:0.967989
# [3600]	validation_0-mae:0.950909
# [4000]	validation_0-mae:0.937688
# [4400]	validation_0-mae:0.924877
# [4800]	validation_0-mae:0.914656
# [5200]	validation_0-mae:0.905342
# [5600]	validation_0-mae:0.896026
# [6000]	validation_0-mae:0.889435
# [6400]	validation_0-mae:0.882443
# [6800]	validation_0-mae:0.876298
# [7200]	validation_0-mae:0.87084
# [7600]	validation_0-mae:0.865717
# [8000]	validation_0-mae:0.861287
# Stopping. Best iteration:
# [8108]	validation_0-mae:0.859968
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 8108 Best ntree_limit: 8109 Best score: 0.859968
# fold 3 of 5
# [22:46:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:56.6791
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:1.41007
# [800]	validation_0-mae:1.24369
# [1200]	validation_0-mae:1.15421
# [1600]	validation_0-mae:1.09904
# [2000]	validation_0-mae:1.05876
# [2400]	validation_0-mae:1.02655
# [2800]	validation_0-mae:1.00243
# [3200]	validation_0-mae:0.981846
# [3600]	validation_0-mae:0.965284
# [4000]	validation_0-mae:0.949901
# [4400]	validation_0-mae:0.937123
# [4800]	validation_0-mae:0.926382
# [5200]	validation_0-mae:0.916479
# [5600]	validation_0-mae:0.90912
# [6000]	validation_0-mae:0.902105
# [6400]	validation_0-mae:0.89536
# [6800]	validation_0-mae:0.889033
# [7200]	validation_0-mae:0.883496
# [7600]	validation_0-mae:0.878525
# [8000]	validation_0-mae:0.873208
# Stopping. Best iteration:
# [8337]	validation_0-mae:0.869094
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 8337 Best ntree_limit: 8338 Best score: 0.869094
# fold 4 of 5
# [22:54:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:56.6773
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:1.40583
# [800]	validation_0-mae:1.23924
# [1200]	validation_0-mae:1.15081
# [1600]	validation_0-mae:1.09563
# [2000]	validation_0-mae:1.05642
# [2400]	validation_0-mae:1.02565
# [2800]	validation_0-mae:1.0002
# [3200]	validation_0-mae:0.979996
# [3600]	validation_0-mae:0.96296
# [4000]	validation_0-mae:0.948151
# [4400]	validation_0-mae:0.935933
# [4800]	validation_0-mae:0.925257
# [5200]	validation_0-mae:0.915302
# [5600]	validation_0-mae:0.907192
# [6000]	validation_0-mae:0.900413
# [6400]	validation_0-mae:0.894112
# [6800]	validation_0-mae:0.888088
# [7200]	validation_0-mae:0.883433
# [7600]	validation_0-mae:0.878275
# [8000]	validation_0-mae:0.873456
# [8400]	validation_0-mae:0.869161
# [8800]	validation_0-mae:0.865761
# [9200]	validation_0-mae:0.862392
# [9600]	validation_0-mae:0.859457
# [10000]	validation_0-mae:0.856268
# [10400]	validation_0-mae:0.853154
# [10800]	validation_0-mae:0.850328
# [11200]	validation_0-mae:0.847996
# Stopping. Best iteration:
# [11544]	validation_0-mae:0.846109
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 11544 Best ntree_limit: 11545 Best score: 0.846109
# fold 5 of 5
# [23:06:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:56.6829
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:1.41662
# [800]	validation_0-mae:1.25017
# [1200]	validation_0-mae:1.15881
# [1600]	validation_0-mae:1.10332
# [2000]	validation_0-mae:1.06008
# [2400]	validation_0-mae:1.02773
# [2800]	validation_0-mae:1.00251
# [3200]	validation_0-mae:0.981205
# [3600]	validation_0-mae:0.963097
# [4000]	validation_0-mae:0.948912
# [4400]	validation_0-mae:0.936247
# [4800]	validation_0-mae:0.925224
# [5200]	validation_0-mae:0.91552
# [5600]	validation_0-mae:0.907054
# [6000]	validation_0-mae:0.899841
# [6400]	validation_0-mae:0.89323
# [6800]	validation_0-mae:0.886983
# [7200]	validation_0-mae:0.881302
# [7600]	validation_0-mae:0.87598
# [8000]	validation_0-mae:0.870885
# [8400]	validation_0-mae:0.866866
# [8800]	validation_0-mae:0.8634
# [9200]	validation_0-mae:0.859889
# [9600]	validation_0-mae:0.857016
# [10000]	validation_0-mae:0.853861
# [10400]	validation_0-mae:0.850892
# [10800]	validation_0-mae:0.848577
# [11200]	validation_0-mae:0.846083
# [11600]	validation_0-mae:0.843775
# Stopping. Best iteration:
# [11864]	validation_0-mae:0.842185
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 11864 Best ntree_limit: 11865 Best score: 0.842185
# 1JHC mae 0.8557107982671848
# 1JHC 0.8557107982671848 380609
# RAM usage: 3.514141082763672 GB
#
# ############### 2JHH ###################
#
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 230.37MB to 227.49MB (2.88MB, 1.25% reduction)
# Column 'nn4_0' converted from int16 to int8
# Column 'nn5_0' converted from int16 to int8
# Column 'nn6_0' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'nn5_1' converted from int16 to int8
# Column 'nn6_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 122.62MB to 119.91MB (2.71MB, 2.21% reduction)
# RAM usage: 3.8078269958496094 GB
# 2JHH started...
# fold 1 of 5
# [23:18:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:6.61296
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.328605
# [800]	validation_0-mae:0.285253
# [1200]	validation_0-mae:0.265081
# [1600]	validation_0-mae:0.250809
# [2000]	validation_0-mae:0.242422
# [2400]	validation_0-mae:0.235544
# [2800]	validation_0-mae:0.230314
# [3200]	validation_0-mae:0.225592
# [3600]	validation_0-mae:0.222202
# [4000]	validation_0-mae:0.21906
# [4400]	validation_0-mae:0.216642
# [4800]	validation_0-mae:0.214514
# [5200]	validation_0-mae:0.212602
# [5600]	validation_0-mae:0.210933
# [6000]	validation_0-mae:0.20974
# [6400]	validation_0-mae:0.208363
# [6800]	validation_0-mae:0.207246
# Stopping. Best iteration:
# [6944]	validation_0-mae:0.206912
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 6944 Best ntree_limit: 6945 Best score: 0.206912
# fold 2 of 5
# [23:21:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:6.6309
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.325682
# [800]	validation_0-mae:0.282343
# [1200]	validation_0-mae:0.260199
# [1600]	validation_0-mae:0.24734
# [2000]	validation_0-mae:0.238384
# [2400]	validation_0-mae:0.231101
# [2800]	validation_0-mae:0.225802
# [3200]	validation_0-mae:0.22117
# [3600]	validation_0-mae:0.21816
# [4000]	validation_0-mae:0.215392
# [4400]	validation_0-mae:0.212976
# [4800]	validation_0-mae:0.210821
# [5200]	validation_0-mae:0.209095
# [5600]	validation_0-mae:0.207355
# [6000]	validation_0-mae:0.206094
# [6400]	validation_0-mae:0.204699
# [6800]	validation_0-mae:0.203541
# [7200]	validation_0-mae:0.202497
# [7600]	validation_0-mae:0.201643
# [8000]	validation_0-mae:0.200855
# [8400]	validation_0-mae:0.200124
# Stopping. Best iteration:
# [8746]	validation_0-mae:0.199594
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 8746 Best ntree_limit: 8747 Best score: 0.199594
# fold 3 of 5
# [23:25:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:6.63428
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.329796
# [800]	validation_0-mae:0.283964
# [1200]	validation_0-mae:0.262663
# [1600]	validation_0-mae:0.249614
# [2000]	validation_0-mae:0.240798
# [2400]	validation_0-mae:0.233533
# [2800]	validation_0-mae:0.228149
# [3200]	validation_0-mae:0.223706
# [3600]	validation_0-mae:0.220483
# [4000]	validation_0-mae:0.217607
# [4400]	validation_0-mae:0.215103
# [4800]	validation_0-mae:0.2132
# [5200]	validation_0-mae:0.211357
# [5600]	validation_0-mae:0.20957
# Stopping. Best iteration:
# [5710]	validation_0-mae:0.209195
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 5710 Best ntree_limit: 5711 Best score: 0.209195
# fold 4 of 5
# [23:28:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:6.62768
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.324566
# [800]	validation_0-mae:0.281439
# [1200]	validation_0-mae:0.260992
# [1600]	validation_0-mae:0.248407
# [2000]	validation_0-mae:0.239377
# [2400]	validation_0-mae:0.232463
# [2800]	validation_0-mae:0.227199
# [3200]	validation_0-mae:0.223074
# [3600]	validation_0-mae:0.219497
# [4000]	validation_0-mae:0.216517
# [4400]	validation_0-mae:0.213734
# [4800]	validation_0-mae:0.211557
# [5200]	validation_0-mae:0.210155
# [5600]	validation_0-mae:0.20849
# Stopping. Best iteration:
# [5697]	validation_0-mae:0.208146
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 5697 Best ntree_limit: 5698 Best score: 0.208146
# fold 5 of 5
# [23:31:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:6.64173
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.32526
# [800]	validation_0-mae:0.282578
# [1200]	validation_0-mae:0.260894
# [1600]	validation_0-mae:0.246814
# [2000]	validation_0-mae:0.237923
# [2400]	validation_0-mae:0.231389
# [2800]	validation_0-mae:0.226494
# [3200]	validation_0-mae:0.221901
# [3600]	validation_0-mae:0.218048
# [4000]	validation_0-mae:0.215159
# [4400]	validation_0-mae:0.212736
# [4800]	validation_0-mae:0.210738
# Stopping. Best iteration:
# [5089]	validation_0-mae:0.209531
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 5089 Best ntree_limit: 5090 Best score: 0.209531
# 2JHH mae 0.20667548998595597
# 2JHH 0.20667548998595597 203126
# RAM usage: 3.2285308837890625 GB
#
# ############### 1JHN ###################
#
# Column 'nn3_0' converted from int16 to int8
# Column 'nn3_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 26.43MB to 26.01MB (0.41MB, 1.56% reduction)
# Column 'nn4_0' converted from int16 to int8
# Column 'nn5_0' converted from int16 to int8
# Column 'nn6_0' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'nn5_1' converted from int16 to int8
# Column 'nn6_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 14.61MB to 14.28MB (0.32MB, 2.21% reduction)
# RAM usage: 3.2285308837890625 GB
# 1JHN started...
# fold 1 of 5
# [23:34:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:42.2314
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.600878
# [800]	validation_0-mae:0.506084
# [1200]	validation_0-mae:0.461488
# [1600]	validation_0-mae:0.433324
# [2000]	validation_0-mae:0.415313
# [2400]	validation_0-mae:0.400614
# [2800]	validation_0-mae:0.389109
# [3200]	validation_0-mae:0.379953
# [3600]	validation_0-mae:0.373043
# [4000]	validation_0-mae:0.367238
# [4400]	validation_0-mae:0.362792
# [4800]	validation_0-mae:0.358612
# [5200]	validation_0-mae:0.355288
# [5600]	validation_0-mae:0.352541
# [6000]	validation_0-mae:0.349672
# [6400]	validation_0-mae:0.347482
# [6800]	validation_0-mae:0.345364
# [7200]	validation_0-mae:0.343359
# [7600]	validation_0-mae:0.341737
# [8000]	validation_0-mae:0.340087
# Stopping. Best iteration:
# [8205]	validation_0-mae:0.339294
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 8205 Best ntree_limit: 8206 Best score: 0.339294
# fold 2 of 5
# [23:34:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:42.2768
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.609581
# [800]	validation_0-mae:0.512781
# [1200]	validation_0-mae:0.46369
# [1600]	validation_0-mae:0.435912
# [2000]	validation_0-mae:0.415795
# [2400]	validation_0-mae:0.401473
# [2800]	validation_0-mae:0.390052
# [3200]	validation_0-mae:0.380805
# [3600]	validation_0-mae:0.37341
# [4000]	validation_0-mae:0.367973
# [4400]	validation_0-mae:0.363079
# [4800]	validation_0-mae:0.358782
# [5200]	validation_0-mae:0.355196
# [5600]	validation_0-mae:0.351725
# [6000]	validation_0-mae:0.349167
# [6400]	validation_0-mae:0.346836
# Stopping. Best iteration:
# [6412]	validation_0-mae:0.346768
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 6412 Best ntree_limit: 6413 Best score: 0.346768
# fold 3 of 5
# [23:35:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:42.3699
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.600406
# [800]	validation_0-mae:0.506158
# [1200]	validation_0-mae:0.457943
# [1600]	validation_0-mae:0.430158
# [2000]	validation_0-mae:0.411265
# [2400]	validation_0-mae:0.397365
# [2800]	validation_0-mae:0.385719
# [3200]	validation_0-mae:0.378522
# [3600]	validation_0-mae:0.371793
# [4000]	validation_0-mae:0.366307
# [4400]	validation_0-mae:0.361259
# [4800]	validation_0-mae:0.356995
# [5200]	validation_0-mae:0.353417
# [5600]	validation_0-mae:0.350377
# [6000]	validation_0-mae:0.347612
# [6400]	validation_0-mae:0.345023
# [6800]	validation_0-mae:0.342473
# [7200]	validation_0-mae:0.340555
# [7600]	validation_0-mae:0.338807
# [8000]	validation_0-mae:0.337393
# [8400]	validation_0-mae:0.335906
# [8800]	validation_0-mae:0.334444
# [9200]	validation_0-mae:0.333142
# Stopping. Best iteration:
# [9239]	validation_0-mae:0.333038
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 9239 Best ntree_limit: 9240 Best score: 0.333038
# fold 4 of 5
# [23:35:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:42.2717
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.606152
# [800]	validation_0-mae:0.509583
# [1200]	validation_0-mae:0.463037
# [1600]	validation_0-mae:0.434603
# [2000]	validation_0-mae:0.415592
# [2400]	validation_0-mae:0.400929
# [2800]	validation_0-mae:0.389996
# [3200]	validation_0-mae:0.381787
# [3600]	validation_0-mae:0.374312
# [4000]	validation_0-mae:0.36798
# [4400]	validation_0-mae:0.362801
# [4800]	validation_0-mae:0.358531
# [5200]	validation_0-mae:0.355092
# [5600]	validation_0-mae:0.351872
# [6000]	validation_0-mae:0.349388
# [6400]	validation_0-mae:0.346927
# [6800]	validation_0-mae:0.344997
# [7200]	validation_0-mae:0.343026
# [7600]	validation_0-mae:0.341163
# [8000]	validation_0-mae:0.339709
# Stopping. Best iteration:
# [8061]	validation_0-mae:0.339482
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 8061 Best ntree_limit: 8062 Best score: 0.339482
# fold 5 of 5
# [23:36:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:42.2673
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.585963
# [800]	validation_0-mae:0.498571
# [1200]	validation_0-mae:0.455699
# [1600]	validation_0-mae:0.430098
# [2000]	validation_0-mae:0.411588
# [2400]	validation_0-mae:0.397165
# [2800]	validation_0-mae:0.387484
# [3200]	validation_0-mae:0.379214
# [3600]	validation_0-mae:0.372641
# [4000]	validation_0-mae:0.367667
# [4400]	validation_0-mae:0.362696
# [4800]	validation_0-mae:0.358216
# [5200]	validation_0-mae:0.354698
# [5600]	validation_0-mae:0.351888
# [6000]	validation_0-mae:0.348614
# [6400]	validation_0-mae:0.346112
# Stopping. Best iteration:
# [6686]	validation_0-mae:0.344317
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 6686 Best ntree_limit: 6687 Best score: 0.344317
# 1JHN mae 0.34057997605970136
# 1JHN 0.34057997605970136 24195
# RAM usage: 2.7774505615234375 GB
#
# ############### 2JHN ###################
#
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 72.67MB to 71.76MB (0.91MB, 1.25% reduction)
# Column 'nn4_0' converted from int16 to int8
# Column 'nn5_0' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'nn5_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 38.89MB to 38.15MB (0.74MB, 1.90% reduction)
# RAM usage: 2.8701324462890625 GB
# 2JHN started...
# fold 1 of 5
# [23:37:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.85187
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.424882
# [800]	validation_0-mae:0.352607
# [1200]	validation_0-mae:0.316638
# [1600]	validation_0-mae:0.294886
# [2000]	validation_0-mae:0.278897
# [2400]	validation_0-mae:0.267073
# [2800]	validation_0-mae:0.257732
# [3200]	validation_0-mae:0.250268
# [3600]	validation_0-mae:0.243942
# [4000]	validation_0-mae:0.238544
# [4400]	validation_0-mae:0.234019
# [4800]	validation_0-mae:0.230061
# [5200]	validation_0-mae:0.226369
# [5600]	validation_0-mae:0.223217
# [6000]	validation_0-mae:0.220432
# [6400]	validation_0-mae:0.217853
# [6800]	validation_0-mae:0.21549
# [7200]	validation_0-mae:0.213369
# [7600]	validation_0-mae:0.211671
# [8000]	validation_0-mae:0.210055
# [8400]	validation_0-mae:0.208442
# [8800]	validation_0-mae:0.206918
# [9200]	validation_0-mae:0.205599
# [9600]	validation_0-mae:0.204368
# [10000]	validation_0-mae:0.203159
# [10400]	validation_0-mae:0.202089
# [10800]	validation_0-mae:0.201113
# [11200]	validation_0-mae:0.200084
# [11600]	validation_0-mae:0.199044
# [12000]	validation_0-mae:0.19814
# [12400]	validation_0-mae:0.19737
# [12800]	validation_0-mae:0.196749
# [13200]	validation_0-mae:0.196037
# [13600]	validation_0-mae:0.195386
# [14000]	validation_0-mae:0.194869
# [14400]	validation_0-mae:0.194173
# [14800]	validation_0-mae:0.193669
# [15200]	validation_0-mae:0.193059
# [15600]	validation_0-mae:0.192596
# Stopping. Best iteration:
# [15894]	validation_0-mae:0.192218
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 15894 Best ntree_limit: 15895 Best score: 0.192218
# fold 2 of 5
# [23:39:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.87852
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.423142
# [800]	validation_0-mae:0.355218
# [1200]	validation_0-mae:0.321187
# [1600]	validation_0-mae:0.297399
# [2000]	validation_0-mae:0.281988
# [2400]	validation_0-mae:0.269738
# [2800]	validation_0-mae:0.260148
# [3200]	validation_0-mae:0.252479
# [3600]	validation_0-mae:0.245827
# [4000]	validation_0-mae:0.240262
# [4400]	validation_0-mae:0.235265
# [4800]	validation_0-mae:0.231155
# [5200]	validation_0-mae:0.227399
# [5600]	validation_0-mae:0.224379
# [6000]	validation_0-mae:0.221415
# [6400]	validation_0-mae:0.21899
# [6800]	validation_0-mae:0.216857
# [7200]	validation_0-mae:0.214755
# [7600]	validation_0-mae:0.212877
# [8000]	validation_0-mae:0.211274
# [8400]	validation_0-mae:0.209614
# [8800]	validation_0-mae:0.208414
# [9200]	validation_0-mae:0.207033
# [9600]	validation_0-mae:0.205744
# [10000]	validation_0-mae:0.204589
# [10400]	validation_0-mae:0.203597
# [10800]	validation_0-mae:0.202515
# [11200]	validation_0-mae:0.201482
# [11600]	validation_0-mae:0.200494
# [12000]	validation_0-mae:0.19959
# [12400]	validation_0-mae:0.198769
# Stopping. Best iteration:
# [12460]	validation_0-mae:0.198656
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 12460 Best ntree_limit: 12461 Best score: 0.198656
# fold 3 of 5
# [23:41:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.82901
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.414775
# [800]	validation_0-mae:0.347837
# [1200]	validation_0-mae:0.313378
# [1600]	validation_0-mae:0.291537
# [2000]	validation_0-mae:0.276125
# [2400]	validation_0-mae:0.2641
# [2800]	validation_0-mae:0.255371
# [3200]	validation_0-mae:0.247686
# [3600]	validation_0-mae:0.241491
# [4000]	validation_0-mae:0.236546
# [4400]	validation_0-mae:0.23197
# [4800]	validation_0-mae:0.227957
# [5200]	validation_0-mae:0.224431
# [5600]	validation_0-mae:0.22151
# [6000]	validation_0-mae:0.218961
# [6400]	validation_0-mae:0.216509
# [6800]	validation_0-mae:0.21446
# [7200]	validation_0-mae:0.212689
# [7600]	validation_0-mae:0.210859
# [8000]	validation_0-mae:0.209285
# [8400]	validation_0-mae:0.207807
# [8800]	validation_0-mae:0.206555
# [9200]	validation_0-mae:0.205225
# [9600]	validation_0-mae:0.204148
# [10000]	validation_0-mae:0.203038
# [10400]	validation_0-mae:0.201962
# [10800]	validation_0-mae:0.201043
# [11200]	validation_0-mae:0.200047
# [11600]	validation_0-mae:0.199251
# [12000]	validation_0-mae:0.19838
# [12400]	validation_0-mae:0.197632
# [12800]	validation_0-mae:0.196873
# [13200]	validation_0-mae:0.196242
# [13600]	validation_0-mae:0.195665
# [14000]	validation_0-mae:0.195024
# [14400]	validation_0-mae:0.194504
# [14800]	validation_0-mae:0.194012
# [15200]	validation_0-mae:0.193455
# Stopping. Best iteration:
# [15573]	validation_0-mae:0.192954
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 15573 Best ntree_limit: 15574 Best score: 0.192954
# fold 4 of 5
# [23:44:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.87102
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.423082
# [800]	validation_0-mae:0.353101
# [1200]	validation_0-mae:0.318537
# [1600]	validation_0-mae:0.29606
# [2000]	validation_0-mae:0.280218
# [2400]	validation_0-mae:0.268207
# [2800]	validation_0-mae:0.25868
# [3200]	validation_0-mae:0.250923
# [3600]	validation_0-mae:0.244777
# [4000]	validation_0-mae:0.239719
# [4400]	validation_0-mae:0.234733
# [4800]	validation_0-mae:0.230852
# [5200]	validation_0-mae:0.227278
# [5600]	validation_0-mae:0.224126
# [6000]	validation_0-mae:0.221331
# [6400]	validation_0-mae:0.218694
# [6800]	validation_0-mae:0.216445
# [7200]	validation_0-mae:0.214402
# [7600]	validation_0-mae:0.212557
# [8000]	validation_0-mae:0.21081
# [8400]	validation_0-mae:0.209232
# [8800]	validation_0-mae:0.207849
# [9200]	validation_0-mae:0.206569
# [9600]	validation_0-mae:0.205264
# [10000]	validation_0-mae:0.203898
# Stopping. Best iteration:
# [10168]	validation_0-mae:0.203463
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 10168 Best ntree_limit: 10169 Best score: 0.203463
# fold 5 of 5
# [23:45:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.89356
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.42197
# [800]	validation_0-mae:0.35399
# [1200]	validation_0-mae:0.318331
# [1600]	validation_0-mae:0.296468
# [2000]	validation_0-mae:0.280624
# [2400]	validation_0-mae:0.268948
# [2800]	validation_0-mae:0.260055
# [3200]	validation_0-mae:0.252365
# [3600]	validation_0-mae:0.246385
# [4000]	validation_0-mae:0.241197
# [4400]	validation_0-mae:0.236513
# [4800]	validation_0-mae:0.232603
# [5200]	validation_0-mae:0.228774
# [5600]	validation_0-mae:0.225536
# [6000]	validation_0-mae:0.22267
# [6400]	validation_0-mae:0.219963
# [6800]	validation_0-mae:0.217934
# [7200]	validation_0-mae:0.215916
# [7600]	validation_0-mae:0.214014
# [8000]	validation_0-mae:0.212259
# [8400]	validation_0-mae:0.210827
# [8800]	validation_0-mae:0.209242
# [9200]	validation_0-mae:0.207862
# [9600]	validation_0-mae:0.20656
# [10000]	validation_0-mae:0.205384
# [10400]	validation_0-mae:0.204277
# [10800]	validation_0-mae:0.203243
# [11200]	validation_0-mae:0.202283
# [11600]	validation_0-mae:0.201384
# [12000]	validation_0-mae:0.20041
# [12400]	validation_0-mae:0.199619
# [12800]	validation_0-mae:0.198874
# [13200]	validation_0-mae:0.198263
# [13600]	validation_0-mae:0.197624
# ...
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 15912 Best ntree_limit: 15913 Best score: 0.193978
# 2JHN mae 0.19625383151786358
# 2JHN 0.19625383151786358 64424
# RAM usage: 3.023509979248047 GB
#
# ############### 3JHH ###################
#
# Column 'nn3_0' converted from int16 to int8
# Column 'nn4_0' converted from int16 to int8
# Column 'nn5_0' converted from int16 to int8
# Column 'nn3_1' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'nn5_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 359.92MB to 352.03MB (7.89MB, 2.19% reduction)
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 191.63MB to 189.21MB (2.42MB, 1.26% reduction)
# RAM usage: 3.4823837280273438 GB
# 3JHH started...
# fold 1 of 5
# [23:48:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.85013
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.376
# [800]	validation_0-mae:0.330689
# [1200]	validation_0-mae:0.307008
# [1600]	validation_0-mae:0.291476
# [2000]	validation_0-mae:0.281038
# [2400]	validation_0-mae:0.272785
# [2800]	validation_0-mae:0.266692
# [3200]	validation_0-mae:0.261524
# [3600]	validation_0-mae:0.257058
# [4000]	validation_0-mae:0.253112
# [4400]	validation_0-mae:0.250115
# [4800]	validation_0-mae:0.247373
# [5200]	validation_0-mae:0.244967
# [5600]	validation_0-mae:0.242817
# [6000]	validation_0-mae:0.240963
# [6400]	validation_0-mae:0.239169
# [6800]	validation_0-mae:0.237664
# [7200]	validation_0-mae:0.236422
# [7600]	validation_0-mae:0.235257
# [8000]	validation_0-mae:0.234192
# [8400]	validation_0-mae:0.233359
# [8800]	validation_0-mae:0.232348
# [9200]	validation_0-mae:0.231635
# Stopping. Best iteration:
# [9484]	validation_0-mae:0.231185
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 9484 Best ntree_limit: 9485 Best score: 0.231185
# fold 2 of 5
# [23:56:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.86277
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.380476
# [800]	validation_0-mae:0.332054
# [1200]	validation_0-mae:0.30859
# [1600]	validation_0-mae:0.292658
# [2000]	validation_0-mae:0.281926
# [2400]	validation_0-mae:0.273468
# [2800]	validation_0-mae:0.267079
# [3200]	validation_0-mae:0.262093
# [3600]	validation_0-mae:0.257654
# [4000]	validation_0-mae:0.253906
# [4400]	validation_0-mae:0.250788
# [4800]	validation_0-mae:0.247911
# [5200]	validation_0-mae:0.245791
# [5600]	validation_0-mae:0.243752
# [6000]	validation_0-mae:0.241946
# [6400]	validation_0-mae:0.240382
# [6800]	validation_0-mae:0.239069
# [7200]	validation_0-mae:0.237942
# [7600]	validation_0-mae:0.236656
# [8000]	validation_0-mae:0.23551
# [8400]	validation_0-mae:0.234476
# Stopping. Best iteration:
# [8682]	validation_0-mae:0.233925
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 8682 Best ntree_limit: 8683 Best score: 0.233925
# fold 3 of 5
# [00:03:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.85422
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.382939
# [800]	validation_0-mae:0.335026
# [1200]	validation_0-mae:0.311361
# [1600]	validation_0-mae:0.295671
# [2000]	validation_0-mae:0.284885
# [2400]	validation_0-mae:0.276201
# [2800]	validation_0-mae:0.269669
# [3200]	validation_0-mae:0.264307
# [3600]	validation_0-mae:0.260045
# [4000]	validation_0-mae:0.256214
# [4400]	validation_0-mae:0.25324
# [4800]	validation_0-mae:0.250324
# [5200]	validation_0-mae:0.248066
# [5600]	validation_0-mae:0.245824
# [6000]	validation_0-mae:0.243843
# [6400]	validation_0-mae:0.242012
# [6800]	validation_0-mae:0.240465
# [7200]	validation_0-mae:0.239116
# Stopping. Best iteration:
# [7388]	validation_0-mae:0.238513
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 7388 Best ntree_limit: 7389 Best score: 0.238513
# fold 4 of 5
# [00:09:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.85231
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.382564
# [800]	validation_0-mae:0.33541
# [1200]	validation_0-mae:0.311446
# [1600]	validation_0-mae:0.296026
# [2000]	validation_0-mae:0.28491
# [2400]	validation_0-mae:0.276624
# [2800]	validation_0-mae:0.269718
# [3200]	validation_0-mae:0.264298
# [3600]	validation_0-mae:0.259663
# [4000]	validation_0-mae:0.255593
# [4400]	validation_0-mae:0.252321
# [4800]	validation_0-mae:0.249409
# [5200]	validation_0-mae:0.246991
# [5600]	validation_0-mae:0.244713
# [6000]	validation_0-mae:0.242959
# [6400]	validation_0-mae:0.241172
# [6800]	validation_0-mae:0.23958
# [7200]	validation_0-mae:0.238244
# [7600]	validation_0-mae:0.237179
# [8000]	validation_0-mae:0.235905
# [8400]	validation_0-mae:0.234807
# [8800]	validation_0-mae:0.233898
# [9200]	validation_0-mae:0.233082
# Stopping. Best iteration:
# [9214]	validation_0-mae:0.233029
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 9214 Best ntree_limit: 9215 Best score: 0.233029
# fold 5 of 5
# [00:16:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.8472
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.379745
# [800]	validation_0-mae:0.332752
# [1200]	validation_0-mae:0.309075
# [1600]	validation_0-mae:0.29412
# [2000]	validation_0-mae:0.282976
# [2400]	validation_0-mae:0.274802
# [2800]	validation_0-mae:0.267751
# [3200]	validation_0-mae:0.262738
# [3600]	validation_0-mae:0.258388
# [4000]	validation_0-mae:0.254337
# [4400]	validation_0-mae:0.250962
# [4800]	validation_0-mae:0.248162
# [5200]	validation_0-mae:0.245715
# [5600]	validation_0-mae:0.243422
# [6000]	validation_0-mae:0.241492
# [6400]	validation_0-mae:0.239863
# [6800]	validation_0-mae:0.238636
# Stopping. Best iteration:
# [7175]	validation_0-mae:0.237321
#
# ## lr: 0.4 n_est: 20000
# Best iteration: 7175 Best ntree_limit: 7176 Best score: 0.237321
# 3JHH mae 0.2347947059760685
# 3JHH 0.2347947059760685 317435
# RAM usage: 3.939136505126953 GB
#
# ############### 3JHN ###################
#
# Column 'nn3_0' converted from int16 to int8
# Column 'nn4_0' converted from int16 to int8
# Column 'nn3_1' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 101.41MB to 99.51MB (1.90MB, 1.88% reduction)
# Column 'nn4_0' converted from int16 to int8
# Column 'nn5_0' converted from int16 to int8
# Column 'nn4_1' converted from int16 to int8
# Column 'nn5_1' converted from int16 to int8
# Column 'vander_0' converted from float64 to float32
# Column 'vander_1' converted from float64 to float32
# Memory usage decreased from 54.70MB to 53.67MB (1.04MB, 1.90% reduction)
# RAM usage: 4.069026947021484 GB
# 3JHN started...
# fold 1 of 5
# [00:22:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:0.887591
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.288852
# [800]	validation_0-mae:0.245574
# [1200]	validation_0-mae:0.224038
# [1600]	validation_0-mae:0.209635
# [2000]	validation_0-mae:0.200126
# [2400]	validation_0-mae:0.193082
# [2800]	validation_0-mae:0.187242
# [3200]	validation_0-mae:0.182248
# [3600]	validation_0-mae:0.178347
# [4000]	validation_0-mae:0.174722
# [4400]	validation_0-mae:0.171627
# [4800]	validation_0-mae:0.168835
# [5200]	validation_0-mae:0.166563
# [5600]	validation_0-mae:0.164489
# [6000]	validation_0-mae:0.162627
# [6400]	validation_0-mae:0.160909
# [6800]	validation_0-mae:0.159464
# [7200]	validation_0-mae:0.158153
# [7600]	validation_0-mae:0.15679
# [8000]	validation_0-mae:0.155551
# [8400]	validation_0-mae:0.154475
# [8800]	validation_0-mae:0.153343
# [9200]	validation_0-mae:0.152445
# [9600]	validation_0-mae:0.151437
# [10000]	validation_0-mae:0.15056
# [10400]	validation_0-mae:0.149811
# [10800]	validation_0-mae:0.149016
# [11200]	validation_0-mae:0.148393
# [11600]	validation_0-mae:0.147682
# [12000]	validation_0-mae:0.146972
# [12400]	validation_0-mae:0.146404
# [12800]	validation_0-mae:0.145828
# [13200]	validation_0-mae:0.145235
# [13600]	validation_0-mae:0.144734
# [14000]	validation_0-mae:0.144223
# [14400]	validation_0-mae:0.143686
# [14800]	validation_0-mae:0.143217
# [15200]	validation_0-mae:0.142763
# [15600]	validation_0-mae:0.14235
# [16000]	validation_0-mae:0.142008
# [16400]	validation_0-mae:0.141702
# Stopping. Best iteration:
# [16649]	validation_0-mae:0.141481
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 16649 Best ntree_limit: 16650 Best score: 0.141481
# fold 2 of 5
# [00:26:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:0.882541
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.284922
# [800]	validation_0-mae:0.244966
# [1200]	validation_0-mae:0.223298
# [1600]	validation_0-mae:0.210637
# [2000]	validation_0-mae:0.200149
# [2400]	validation_0-mae:0.192813
# [2800]	validation_0-mae:0.187308
# [3200]	validation_0-mae:0.182584
# [3600]	validation_0-mae:0.178688
# [4000]	validation_0-mae:0.175111
# [4400]	validation_0-mae:0.171943
# [4800]	validation_0-mae:0.169208
# [5200]	validation_0-mae:0.167047
# [5600]	validation_0-mae:0.164839
# [6000]	validation_0-mae:0.162908
# [6400]	validation_0-mae:0.161198
# [6800]	validation_0-mae:0.159738
# [7200]	validation_0-mae:0.158171
# [7600]	validation_0-mae:0.156779
# [8000]	validation_0-mae:0.155479
# [8400]	validation_0-mae:0.154309
# [8800]	validation_0-mae:0.153256
# [9200]	validation_0-mae:0.152309
# [9600]	validation_0-mae:0.151218
# [10000]	validation_0-mae:0.150324
# [10400]	validation_0-mae:0.149457
# [10800]	validation_0-mae:0.148668
# [11200]	validation_0-mae:0.147866
# [11600]	validation_0-mae:0.147181
# [12000]	validation_0-mae:0.146481
# [12400]	validation_0-mae:0.145865
# [12800]	validation_0-mae:0.145239
# [13200]	validation_0-mae:0.144756
# [13600]	validation_0-mae:0.144224
# [14000]	validation_0-mae:0.143707
# [14400]	validation_0-mae:0.143242
# [14800]	validation_0-mae:0.142791
# [15200]	validation_0-mae:0.14239
# [15600]	validation_0-mae:0.141988
# [16000]	validation_0-mae:0.14158
# [16400]	validation_0-mae:0.141236
# [16800]	validation_0-mae:0.140825
# Stopping. Best iteration:
# [16959]	validation_0-mae:0.140678
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 16959 Best ntree_limit: 16960 Best score: 0.140678
# fold 3 of 5
# [00:29:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:0.880452
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.28476
# [800]	validation_0-mae:0.243128
# [1200]	validation_0-mae:0.221428
# [1600]	validation_0-mae:0.208456
# [2000]	validation_0-mae:0.198379
# [2400]	validation_0-mae:0.191604
# [2800]	validation_0-mae:0.185689
# [3200]	validation_0-mae:0.181102
# [3600]	validation_0-mae:0.177107
# [4000]	validation_0-mae:0.173353
# [4400]	validation_0-mae:0.170466
# [4800]	validation_0-mae:0.16813
# [5200]	validation_0-mae:0.165658
# [5600]	validation_0-mae:0.163635
# [6000]	validation_0-mae:0.161781
# [6400]	validation_0-mae:0.160015
# [6800]	validation_0-mae:0.15835
# [7200]	validation_0-mae:0.156839
# [7600]	validation_0-mae:0.155539
# [8000]	validation_0-mae:0.154169
# [8400]	validation_0-mae:0.153059
# [8800]	validation_0-mae:0.151975
# [9200]	validation_0-mae:0.150991
# [9600]	validation_0-mae:0.14999
# [10000]	validation_0-mae:0.14913
# [10400]	validation_0-mae:0.148352
# [10800]	validation_0-mae:0.147578
# [11200]	validation_0-mae:0.146848
# [11600]	validation_0-mae:0.146214
# [12000]	validation_0-mae:0.14554
# [12400]	validation_0-mae:0.144846
# [12800]	validation_0-mae:0.144283
# [13200]	validation_0-mae:0.143635
# [13600]	validation_0-mae:0.143064
# [14000]	validation_0-mae:0.142551
# [14400]	validation_0-mae:0.142186
# [14800]	validation_0-mae:0.141718
# [15200]	validation_0-mae:0.141286
# [15600]	validation_0-mae:0.140869
# [16000]	validation_0-mae:0.140452
# [16400]	validation_0-mae:0.1401
# [16800]	validation_0-mae:0.139776
# [17200]	validation_0-mae:0.13942
# [17600]	validation_0-mae:0.139106
# [18000]	validation_0-mae:0.138776
# Stopping. Best iteration:
# [18027]	validation_0-mae:0.13875
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 18027 Best ntree_limit: 18028 Best score: 0.13875
# fold 4 of 5
# [00:33:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:0.869219
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.285429
# [800]	validation_0-mae:0.243981
# [1200]	validation_0-mae:0.222689
# [1600]	validation_0-mae:0.209477
# [2000]	validation_0-mae:0.199651
# [2400]	validation_0-mae:0.19246
# [2800]	validation_0-mae:0.186769
# [3200]	validation_0-mae:0.182004
# [3600]	validation_0-mae:0.177976
# [4000]	validation_0-mae:0.174288
# [4400]	validation_0-mae:0.171364
# [4800]	validation_0-mae:0.168668
# [5200]	validation_0-mae:0.166292
# [5600]	validation_0-mae:0.164051
# [6000]	validation_0-mae:0.162112
# [6400]	validation_0-mae:0.16038
# [6800]	validation_0-mae:0.158706
# [7200]	validation_0-mae:0.157311
# [7600]	validation_0-mae:0.156101
# [8000]	validation_0-mae:0.154927
# [8400]	validation_0-mae:0.153796
# [8800]	validation_0-mae:0.152845
# [9200]	validation_0-mae:0.151927
# [9600]	validation_0-mae:0.150993
# [10000]	validation_0-mae:0.150091
# [10400]	validation_0-mae:0.149287
# [10800]	validation_0-mae:0.148558
# [11200]	validation_0-mae:0.147759
# [11600]	validation_0-mae:0.14711
# [12000]	validation_0-mae:0.146524
# [12400]	validation_0-mae:0.145928
# [12800]	validation_0-mae:0.145293
# Stopping. Best iteration:
# [13158]	validation_0-mae:0.144825
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 13158 Best ntree_limit: 13159 Best score: 0.144825
# fold 5 of 5
# [00:36:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:0.881242
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [400]	validation_0-mae:0.28236
# [800]	validation_0-mae:0.24205
# [1200]	validation_0-mae:0.220584
# [1600]	validation_0-mae:0.206404
# [2000]	validation_0-mae:0.197664
# [2400]	validation_0-mae:0.19005
# [2800]	validation_0-mae:0.184269
# [3200]	validation_0-mae:0.179125
# [3600]	validation_0-mae:0.175308
# [4000]	validation_0-mae:0.172143
# [4400]	validation_0-mae:0.169285
# [4800]	validation_0-mae:0.166497
# [5200]	validation_0-mae:0.164066
# [5600]	validation_0-mae:0.16193
# [6000]	validation_0-mae:0.159923
# [6400]	validation_0-mae:0.158296
# [6800]	validation_0-mae:0.156884
# [7200]	validation_0-mae:0.155363
# [7600]	validation_0-mae:0.154086
# [8000]	validation_0-mae:0.15303
# [8400]	validation_0-mae:0.151921
# [8800]	validation_0-mae:0.150887
# [9200]	validation_0-mae:0.149939
# [9600]	validation_0-mae:0.149046
# [10000]	validation_0-mae:0.148171
# [10400]	validation_0-mae:0.14741
# [10800]	validation_0-mae:0.146609
# [11200]	validation_0-mae:0.145876
# [11600]	validation_0-mae:0.145267
# [12000]	validation_0-mae:0.144548
# [12400]	validation_0-mae:0.143953
# [12800]	validation_0-mae:0.14339
# [13200]	validation_0-mae:0.142864
# [13600]	validation_0-mae:0.142393
# [14000]	validation_0-mae:0.14187
# [14400]	validation_0-mae:0.141375
# [14800]	validation_0-mae:0.14088
# [15200]	validation_0-mae:0.140492
# [15600]	validation_0-mae:0.140091
# [16000]	validation_0-mae:0.139711
# [16400]	validation_0-mae:0.139325
# [16800]	validation_0-mae:0.138968
# [17200]	validation_0-mae:0.138676
# [17600]	validation_0-mae:0.138409
# [18000]	validation_0-mae:0.138144
# [18400]	validation_0-mae:0.137827
# Stopping. Best iteration:
# [18625]	validation_0-mae:0.137642
#
# ## lr: 0.1 n_est: 20000
# Best iteration: 18625 Best ntree_limit: 18626 Best score: 0.137642
# 3JHN mae 0.1406753838387492
# 3JHN 0.1406753838387492 90616
# RAM usage: 3.4269981384277344 GB
# CPU times: user 1h 10min 23s, sys: 6h 27min 36s, total: 7h 38min
# Wall time: 7h 38min 14s

# %%
#.469686

# %%
#fin_preds

# %%
model.get_booster().feature_names=features
model.feature_types = None
fig, ax = plt.subplots(1,1,figsize=(10,20))
plot_importance(model, max_num_features = 200, ax=ax)

# %% [markdown]
# #### print('mae:',mmae(yoof, y_train_wctn))

# %%
#analyse_diff = X_train_wctn.merge(np.abs(predsNN-y_valid_nn).sort_values(ascending=False).to_frame(), left_index=True, right_index=True, copy=False)

#analyse_diff.sort_values(by='scalar_coupling_constant_y').tail(n=10)

# %%
np.mean(raa_all),raa_all, 'minVal of Preds:' ,[np.min(i) for i in fin_preds]
# Out:
# (0.3433492366754473,
#  [0.3913328154398943,
#   0.3807708923181608,
#   0.8557107982671848,
#   0.20667548998595597,
#   0.34057997605970136,
#   0.19625383151786358,
#   0.2347947059760685,
#   0.1406753838387492],
#  'minVal of Preds:',
#  [-17.108029556274413,
#   -31.490022659301758,
#   67.45145263671876,
#   -26.30401496887207,
#   28.154132461547853,
#   -3.448999214172363,
#   -2.258906841278076,
#   -1.6749153137207031])

# %%
#np.concatenate(fin_preds),np.concatenate(fin_preds_idx)

# %%
output = pd.DataFrame({'id': np.concatenate(fin_preds_idx),
                       'scalar_coupling_constant': np.concatenate(fin_preds)})
output.to_csv('submission_last.csv', index=False)



print('Done!')
# Out:
# Done!

# %%
output2 = pd.DataFrame({'id': np.concatenate(fin_train_idx),
                       'scalar_coupling_constant': np.concatenate(nn_preds_valid_a)})
output2.to_csv('train_valid.csv', index=False)



print('Done!')
# Out:
# Done!

# %%
#train[dep_var].hist(), 
plt.hist(np.concatenate(fin_preds))
# Out:
# (array([1.803130e+05, 1.909911e+06, 1.868600e+04, 1.485700e+04,
#         1.899570e+05, 1.357550e+05, 4.718200e+04, 4.024000e+03,
#         2.000000e+00, 4.855000e+03]),
#  array([-31.49002266,  -7.58983479,  16.31035309,  40.21054096,
#          64.11072884,  88.01091671, 111.91110458, 135.81129246,
#         159.71148033, 183.61166821, 207.51185608]),
#  <a list of 10 Patch objects>)

# %%
for i,t in enumerate(types_to_run):
    plt.figure(figsize=(6,6))
    plt.scatter(x=y_valid_nn_a[i], y=nn_preds_valid_a[i])
    
    llim =min(np.min(nn_preds_valid_a[i]),np.min(y_valid_nn_a[i]))-10
    ulim=max(np.max(nn_preds_valid_a[i]),np.max(y_valid_nn_a[i]))+10
    
    plt.xlabel('scalar_coupling_constant')
    plt.ylabel('predicted')
    plt.xlim((llim, ulim))
    plt.ylim((llim, ulim))
    plt.plot([llim, ulim], [llim, ulim])
    plt.title(t, fontsize=18)
    plt.show()

# %% [markdown]
# ## Predictions

# %%
for i,t in enumerate(types_to_run):
    plt.figure(figsize=(6,6))
    
    plt.scatter(x=fin_preds[i], y=fin_preds[i])
    
    plt.xlabel('scalar_coupling_constant')
    plt.ylabel('predicted')
    plt.title(t, fontsize=18)
    plt.show()
